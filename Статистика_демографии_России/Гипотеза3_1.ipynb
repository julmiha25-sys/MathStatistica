# %% [markdown]
# <a href="https://colab.research.google.com/github/julmiha25-sys/MathStatistica/blob/main/%D0%A1%D1%82%D0%B0%D1%82%D0%B8%D1%81%D1%82%D0%B8%D0%BA%D0%B0_%D0%B4%D0%B5%D0%BC%D0%BE%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%B8_%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B8/%D0%93%D0%B8%D0%BF%D0%BE%D1%82%D0%B5%D0%B7%D0%B03_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pandas as pd
from scipy.stats import *
import scipy
from scipy.stats import alexandergovern
df=pd.read_csv('russian_demography.csv', header=0)
group_2015 = df[df['year'] == 2015]['birth_rate'].values
group_2016 = df[df['year'] == 2016]['birth_rate'].values
group_2017 = df[df['year'] == 2017]['birth_rate'].values
groups = [group_2015, group_2016, group_2017]
group_names = ['2015', '2016', '2017']
# Проверка равенство дисперсий по критерию Бартлетта
bartlett(*groups)
# Дисперсии равны - односторонний дисперсионный анализ
f_oneway(*groups)
# Тест Тьюкки для средних
bartlett(*groups),f_oneway(*groups),tukey_hsd(*groups).pvalue
# Out:
# (BartlettResult(statistic=np.float64(0.6594033534095636), pvalue=np.float64(0.7191382371232273)),
#  F_onewayResult(statistic=np.float64(13.832282461665734), pvalue=np.float64(1.995953452152246e-06)),
#  array([[1.00000000e+00, 4.08958415e-01, 2.44447461e-06],
#         [4.08958415e-01, 1.00000000e+00, 5.73305454e-04],
#         [2.44447461e-06, 5.73305454e-04, 1.00000000e+00]]))
