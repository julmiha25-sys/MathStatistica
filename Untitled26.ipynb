# %% [markdown]
# <a href="https://colab.research.google.com/github/julmiha25-sys/MathStatistica/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy
import numpy as np
from scipy.stats import *
from math import *
# Out:
# Статистика по мужчинам:
# Среднее:  63152.30
# Несм. дисперсия:  671153104.66
# Количество:  4977.00
#
# Статистика по женщинам:
# Среднее:  63161.73
# Несм. дисперсия:  652444078.84
# Количество:  5023.00
#
# Критерий Фишера 1.0286752940524901
# Критическая область: (1.068017823965556;+∞)
# Критерий Фишера не лежит в критической области - нет оснований отвергнуть гипотезу о равенстве дисперсий
# Вероятность гипотезы p-value: 0.1588
# Нет оснований отвергнуть гипотезу о равенстве дисперсий
# Критерий Стьюдента -0.0183
# Критическая область: (2.3267209132887694;+∞)
# Критерий Стьюдента не лежит в критической области - нет оснований отвергнуть гипотезу о равенстве средних зарплат мужчины и женщины
# Вероятность гипотезы p-value: 0.5073
# Нет оснований отвергнуть гипотезу о равенстве средних зарплат мужчины и женщины
